# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
df = pd.read_csv('https://raw.githubusercontent.com/getdatachimp/demo/main/prep/borked_iris.csv')
df
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         145           6.7          3.0           5.2          2.3
# 146         146           6.3          2.5           5.0          1.9
# 147         147           6.5          3.0           5.2          2.0
# 148         148           6.2          3.4           5.4          2.3
# 149         149           5.9          3.0           5.1          1.8
#
#        variety collector
# 0       Setosa       Sam
# 1       Setosa       Sam
# 2       Setosa       Sam
# 3       Setosa       Sam
# 4       Setosa       Sam
# ..         ...       ...
# 145  Virginica       Sam
# 146  Virginica       Sam
# 147  Virginica       Sam
# 148  Virginica       Sam
# 149  Virginica       Sam
#
# [150 rows x 7 columns]

# %%
df.drop('Unnamed: 0', axis=1)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety collector
# 0             5.1          3.5           1.4          0.2     Setosa       Sam
# 1             4.9          3.0           1.4          0.2     Setosa       Sam
# 2             4.7          3.2           1.3          0.2     Setosa       Sam
# 3             4.6          3.1           1.5          0.2     Setosa       Sam
# 4             5.0          3.6           1.4          0.2     Setosa       Sam
# ..            ...          ...           ...          ...        ...       ...
# 145           6.7          3.0           5.2          2.3  Virginica       Sam
# 146           6.3          2.5           5.0          1.9  Virginica       Sam
# 147           6.5          3.0           5.2          2.0  Virginica       Sam
# 148           6.2          3.4           5.4          2.3  Virginica       Sam
# 149           5.9          3.0           5.1          1.8  Virginica       Sam
#
# [150 rows x 6 columns]

# %%
df['sepal_length'].plot.hist(legend=True)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
X = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = df['variety'].map({'Setosa': 0, 'Versicolor': 1, 'Virginica': 2})
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
pipeline = make_pipeline(
  StandardScaler(),
  LogisticRegression()
)

model = pipeline.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred)).plot()

# %%
from doubtlab.ensemble import DoubtEnsemble
from doubtlab.reason import ProbaReason, WrongPredictionReason

reasons = {
    'proba': ProbaReason(model=model),
    'wrong_pred': WrongPredictionReason(model=model)
}

doubt = DoubtEnsemble(**reasons)

indices = doubt.get_indices(X_train, y_train)
predicates = doubt.get_predicates(X_train, y_train)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3184/1396537375.py in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
predicates
# Out:
#      predicate_proba  predicate_wrong_pred
# 99               1.0                   1.0
# 55               1.0                   1.0
# 92               1.0                   1.0
# 41               1.0                   1.0
# 96               1.0                   1.0
# ..               ...                   ...
# 120              0.0                   0.0
# 102              0.0                   0.0
# 12               0.0                   0.0
# 109              0.0                   0.0
# 47               0.0                   0.0
#
# [112 rows x 2 columns]

# %%
df = df.join(predicates)
df.iloc[predicates.index].head(len(indices))
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 99           99           5.7          2.8           4.1          1.3
# 55           55           5.7          2.8           4.5          1.3
# 92           92           5.8          2.6           4.0          1.2
# 41           41           4.5          2.3           1.3          0.3
# 96           96           5.7          2.9           4.2          1.3
# 68           68           6.2          2.2           4.5          1.5
# 64           64           5.6          2.9           3.6          1.3
# 61           61           5.9          3.0           4.2          1.5
# 106         106           4.9          2.5           4.5          1.7
# 87           87           6.3          2.3           4.4          1.3
# 142         142           5.8          2.7           5.1          1.9
# 72           72           6.3          2.5           4.9          1.5
# 74           74           6.4          2.9           4.3          1.3
# 91           91           6.1          3.0           4.6          1.4
# 101         101           5.8          2.7           5.1          1.9
# 113         113           5.7          2.5           5.0          2.0
# 119         119           6.0          2.2           5.0          1.5
#
#         variety collector  predicate_proba  predicate_wrong_pred
# 99   Versicolor      Eric              1.0                   1.0
# 55   Versicolor      Eric              1.0                   1.0
# 92   Versicolor      Eric              1.0                   1.0
# 41       Setosa       Sam              1.0                   1.0
# 96   Versicolor      Eric              1.0                   1.0
# 68   Versicolor      Eric              1.0                   1.0
# 64   Versicolor      Eric              1.0                   1.0
# 61   Versicolor      Eric              0.0                   1.0
# 106   Virginica       Sam              0.0                   1.0
# 87   Versicolor      Eric              0.0                   1.0
# 142   Virginica       Sam              1.0                   0.0
# 72   Versicolor      Eric              0.0                   1.0
# 74   Versicolor      Eric              0.0                   1.0
# 91   Versicolor      Eric              0.0                   1.0
# 101   Virginica       Sam              1.0                   0.0
# 113   Virginica       Sam              0.0                   1.0
# 119   Virginica       Sam              0.0                   1.0

# %%
import pandera as pa

schema = pa.DataFrameSchema({
    'variety': pa.Column(str),
    'petal_length': pa.Column(float, [
      pa.Check(lambda g: g['Versicolor'].max() <= 30, groupby='variety'),
      pa.Check(lambda g: g['Setosa'].max() <= 10, groupby='variety'),
      pa.Check(lambda g: g['Virginica'].max() <= 40, groupby='variety'),
    ])
})

schema.validate(df)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# /Users/mattdupree/Developer/datachimp/demo-quality-pipeline/ex1.ipynb Cell 10 in <cell line: 0>()
#       <a href='vscode-notebook-cell:/Users/mattdupree/Developer/datachimp/demo-quality-pipeline/ex1.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> import pandera as pa
#       <a href='vscode-notebook-cell:/Users/mattdupree/Developer/datachimp/demo-quality-pipeline/ex1.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> schema = pa.DataFrameSchema({
#       <a href='vscode-notebook-cell:/Users/mattdupree/Developer/datachimp/demo-quality-pipeline/ex1.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a>     'variety': pa.Column(str),
#       <a href='vscode-notebook-cell:/Users/mattdupree/Developer/datachimp/demo-quality-pipeline/ex1.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a>     'petal_length': pa.Column(float, [
#    (...)
#       <a href='vscode-notebook-cell:/Users/mattdupree/Developer/datachimp/demo-quality-pipeline/ex1.ipynb#X12sZmlsZQ%3D%3D?line=8'>9</a>     ])
#      <a href='vscode-notebook-cell:/Users/mattdupree/Developer/datachimp/demo-quality-pipeline/ex1.ipynb#X12sZmlsZQ%3D%3D?line=9'>10</a> })
# ---> <a href='vscode-notebook-cell:/Users/mattdupree/Developer/datachimp/demo-quality-pipeline/ex1.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> schema.validate(df)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandera/schemas.py:534, in DataFrameSchema.validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     521     check_obj = check_obj.map_partitions(
#     522         self._validate,
#     523         head=head,
#    (...)
#     529         meta=check_obj,
#     530     )
#     532     return check_obj.pandera.add_schema(self)
# --> 534 return self._validate(
#     535     check_obj=check_obj,
#     536     head=head,
#     537     tail=tail,
#     538     sample=sample,
#     539     random_state=random_state,
#     540     lazy=lazy,
#     541     inplace=inplace,
#     542 )
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandera/schemas.py:732, in DataFrameSchema._validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     730     check_results.append(check_utils.is_table(result))
#     731 except errors.SchemaError as err:
# --> 732     error_handler.collect_error("schema_component_check", err)
#     733 except errors.SchemaErrors as err:
#     734     for schema_error_dict in err.schema_errors:
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandera/error_handlers.py:32, in SchemaErrorHandler.collect_error(self, reason_code, schema_error, original_exc)
#      26 """Collect schema error, raising exception if lazy is False.
#      27
#      28 :param reason_code: string representing reason for error
#      29 :param schema_error: ``SchemaError`` object.
#      30 """
#      31 if not self._lazy:
# ---> 32     raise schema_error from original_exc
#      34 # delete data of validated object from SchemaError object to prevent
#      35 # storing copies of the validated DataFrame/Series for every
#      36 # SchemaError collected.
#      37 del schema_error.data
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandera/schemas.py:724, in DataFrameSchema._validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     722 for schema_component in schema_components:
#     723     try:
# --> 724         result = schema_component(
#     725             df_to_validate,
#     726             lazy=lazy,
#     727             # don't make a copy of the data
#     728             inplace=True,
#     729         )
#     730         check_results.append(check_utils.is_table(result))
#     731     except errors.SchemaError as err:
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandera/schemas.py:2138, in SeriesSchemaBase.__call__(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    2127 def __call__(
#    2128     self,
#    2129     check_obj: Union[pd.DataFrame, pd.Series],
#    (...)
#    2135     inplace: bool = False,
#    2136 ) -> Union[pd.DataFrame, pd.Series]:
#    2137     """Alias for ``validate`` method."""
# -> 2138     return self.validate(
#    2139         check_obj, head, tail, sample, random_state, lazy, inplace
#    2140     )
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandera/schema_components.py:223, in Column.validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     219             validate_column(
#     220                 check_obj[column_name].iloc[:, [i]], column_name
#     221             )
#     222     else:
# --> 223         validate_column(check_obj, column_name)
#     225 return check_obj
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandera/schema_components.py:196, in Column.validate.<locals>.validate_column(check_obj, column_name)
#     195 def validate_column(check_obj, column_name):
# --> 196     super(Column, copy(self).set_name(column_name)).validate(
#     197         check_obj,
#     198         head,
#     199         tail,
#     200         sample,
#     201         random_state,
#     202         lazy,
#     203         inplace=inplace,
#     204     )
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandera/schemas.py:2096, in SeriesSchemaBase.validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    2090     check_results.append(
#    2091         _handle_check_results(
#    2092             self, check_index, check, check_obj, *check_args
#    2093         )
#    2094     )
#    2095 except errors.SchemaError as err:
# -> 2096     error_handler.collect_error("dataframe_check", err)
#    2097 except Exception as err:  # pylint: disable=broad-except
#    2098     # catch other exceptions that may occur when executing the
#    2099     # Check
#    2100     err_msg = f'"{err.args[0]}"' if len(err.args) > 0 else ""
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandera/error_handlers.py:32, in SchemaErrorHandler.collect_error(self, reason_code, schema_error, original_exc)
#      26 """Collect schema error, raising exception if lazy is False.
#      27
#      28 :param reason_code: string representing reason for error
#      29 :param schema_error: ``SchemaError`` object.
#      30 """
#      31 if not self._lazy:
# ---> 32     raise schema_error from original_exc
#      34 # delete data of validated object from SchemaError object to prevent
#      35 # storing copies of the validated DataFrame/Series for every
#      36 # SchemaError collected.
#      37 del schema_error.data
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandera/schemas.py:2091, in SeriesSchemaBase.validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    2088 for check_index, check in enumerate(self.checks):
#    2089     try:
#    2090         check_results.append(
# -> 2091             _handle_check_results(
#    2092                 self, check_index, check, check_obj, *check_args
#    2093             )
#    2094         )
#    2095     except errors.SchemaError as err:
#    2096         error_handler.collect_error("dataframe_check", err)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandera/schemas.py:2482, in _handle_check_results(schema, check_index, check, check_obj, *check_args)
#    2480         warnings.warn(error_msg, UserWarning)
#    2481         return True
# -> 2482     raise errors.SchemaError(
#    2483         schema,
#    2484         check_obj,
#    2485         error_msg,
#    2486         failure_cases=failure_cases,
#    2487         check=check,
#    2488         check_index=check_index,
#    2489         check_output=check_result.check_output,
#    2490     )
#    2491 return check_result.check_passed
#
# SchemaError: <Schema Column(name=petal_length, type=DataType(float64))> failed series or dataframe validator 0:
# <Check <lambda>>

# %%
# %connect_info
# Out:
# {
#   "shell_port": 9002,
#   "iopub_port": 9004,
#   "stdin_port": 9003,
#   "control_port": 9001,
#   "hb_port": 9000,
#   "ip": "127.0.0.1",
#   "key": "1cecd395-0f7f-4e52-bd39-7895255f88ef",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-v2-1533dDxUtQlc6vIF.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.
